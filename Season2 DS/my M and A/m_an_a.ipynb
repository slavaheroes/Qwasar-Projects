# %%
import pandas as pd
import numpy as np
import sqlite3 as sql

# %%
df_1 = pd.read_csv("only_wood_customer_us_1.csv")

# %% [markdown]
# Cleaning DF1

# %%
df_1
# Out:
#       Gender FirstName LastName UserName                       Email  Age  \
# 0     Female   latesha   Barton  latesha         forgottoask@woodinc   85
# 1     Female   Yolando     Jast  yolando      yolando_jast@yahoo.com   53
# 2       Male     STACY  JOHNSON    stacy     stacy.johnson@yahoo.com   64
# 3       Male     ABDUL   Mayert    abdul    mayert.abdul@hotmail.com   79
# 4          0    JULIUS  REINGER   julius  reinger_julius@hotmail.com   65
# ...      ...       ...      ...      ...                         ...  ...
# 9995    Male     YOUNG     KOCH    young      koch_young@hotmail.com   44
# 9996    Male     craig    runte    craig       craig.runte@gmail.com   29
# 9997  Female     LEORA  trantow    leora   trantow.leora@hotmail.com   97
# 9998  Female      nery   heller     nery     HELLER_NERY@HOTMAIL.COM   86
# 9999  Female     Linda  dickens    linda     DICKENS.LINDA@YAHOO.COM   58
#
#               City                  Country
# 0     INDIANAPOLIS  United State Of America
# 1         Columbus                       12
# 2     Indianapolis                      NaN
# 3          phoenix                      USA
# 4     Jacksonville                      NaN
# ...            ...                      ...
# 9995  Jacksonville  United State Of America
# 9996  INDIANAPOLIS  United State Of America
# 9997      New-york                      NaN
# 9998      NEW_YORK                      NaN
# 9999     san diego                      NaN
#
# [10000 rows x 8 columns]

# %%
genders = {'0': 'Male', '1': 'Female', 'F': 'Female', 'M': 'Male'}
df_1['Gender'] = df_1['Gender'].replace(genders)
df_1
# Out:
#       Gender FirstName LastName UserName                       Email  Age  \
# 0     Female   latesha   Barton  latesha         forgottoask@woodinc   85
# 1     Female   Yolando     Jast  yolando      yolando_jast@yahoo.com   53
# 2       Male     STACY  JOHNSON    stacy     stacy.johnson@yahoo.com   64
# 3       Male     ABDUL   Mayert    abdul    mayert.abdul@hotmail.com   79
# 4       Male    JULIUS  REINGER   julius  reinger_julius@hotmail.com   65
# ...      ...       ...      ...      ...                         ...  ...
# 9995    Male     YOUNG     KOCH    young      koch_young@hotmail.com   44
# 9996    Male     craig    runte    craig       craig.runte@gmail.com   29
# 9997  Female     LEORA  trantow    leora   trantow.leora@hotmail.com   97
# 9998  Female      nery   heller     nery     HELLER_NERY@HOTMAIL.COM   86
# 9999  Female     Linda  dickens    linda     DICKENS.LINDA@YAHOO.COM   58
#
#               City                  Country
# 0     INDIANAPOLIS  United State Of America
# 1         Columbus                       12
# 2     Indianapolis                      NaN
# 3          phoenix                      USA
# 4     Jacksonville                      NaN
# ...            ...                      ...
# 9995  Jacksonville  United State Of America
# 9996  INDIANAPOLIS  United State Of America
# 9997      New-york                      NaN
# 9998      NEW_YORK                      NaN
# 9999     san diego                      NaN
#
# [10000 rows x 8 columns]

# %%
df_1['FirstName'] = df_1['FirstName'].str.replace('\W', '')
df_1['FirstName'] = df_1['FirstName'].str.title()

df_1['LastName'] = df_1['LastName'].str.replace('\W', '')
df_1['LastName'] = df_1['LastName'].str.title()

df_1['Email'] = df_1['Email'].str.lower()

df_1['City'] = df_1['City'].str.replace('_', '-')
df_1['City'] = df_1['City'].str.title()

df_1['Country'] = 'USA'
df_1
# Out:
#       Gender FirstName LastName UserName                       Email  Age  \
# 0     Female   Latesha   Barton  latesha         forgottoask@woodinc   85
# 1     Female   Yolando     Jast  yolando      yolando_jast@yahoo.com   53
# 2       Male     Stacy  Johnson    stacy     stacy.johnson@yahoo.com   64
# 3       Male     Abdul   Mayert    abdul    mayert.abdul@hotmail.com   79
# 4       Male    Julius  Reinger   julius  reinger_julius@hotmail.com   65
# ...      ...       ...      ...      ...                         ...  ...
# 9995    Male     Young     Koch    young      koch_young@hotmail.com   44
# 9996    Male     Craig    Runte    craig       craig.runte@gmail.com   29
# 9997  Female     Leora  Trantow    leora   trantow.leora@hotmail.com   97
# 9998  Female      Nery   Heller     nery     heller_nery@hotmail.com   86
# 9999  Female     Linda  Dickens    linda     dickens.linda@yahoo.com   58
#
#               City Country
# 0     Indianapolis     USA
# 1         Columbus     USA
# 2     Indianapolis     USA
# 3          Phoenix     USA
# 4     Jacksonville     USA
# ...            ...     ...
# 9995  Jacksonville     USA
# 9996  Indianapolis     USA
# 9997      New-York     USA
# 9998      New-York     USA
# 9999     San Diego     USA
#
# [10000 rows x 8 columns]

# %% [markdown]
# Cleaning DF2

# %%
df_2 = pd.read_csv("only_wood_customer_us_2.csv", sep=';', header=None, 
            names = ['age', 'city', 'gender', 'name', 'email'])
            
df_2.age = df_2.age.str.replace('\D', '')
df_2.name = df_2.name.str.replace('\W', ' ')

df_2.city = df_2.city.str.replace('_', '-')
df_2.city = df_2.city.str.title()

df_2.email = df_2.email.str.lower()

name_df = df_2.name.str.split(expand=True)
df_2['first_name'], df_2['last_name'] = name_df[0], name_df[1]
df_2.drop('name', axis=1, inplace=True)
df_2.first_name = df_2.first_name.str.title()
df_2.last_name = df_2.last_name.str.title()
df_2.gender = df_2.gender.replace(genders)

df_2['country'] = 'USA'

df_2
# Out:
#      age          city  gender                       email first_name  \
# 0     51        Austin  Female     kutch.lorette@gmail.com    Lorette
# 1     84     San Diego  Female     clorinda.wiza@gmail.com   Clorinda
# 2     97      Columbus    Male     littel.joesph@gmail.com     Joesph
# 3     90  Jacksonville    Male      carlo_stokes@gmail.com      Carlo
# 4     57     Charlotte    Male  kasey.prosacco@hotmail.com      Kasey
# ...   ..           ...     ...                         ...        ...
# 9995  60    Fort-Worth  Female    klein.tennille@yahoo.com   Tennille
# 9996  43     San-Diego  Female   suzanna.kunze@hotmail.com    Suzanna
# 9997  19     Charlotte    Male    derick.bartell@gmail.com     Derick
# 9998  46  Indianapolis    Male       tom_block@hotmail.com        Tom
# 9999  59      New-York    Male    allen.hammes@hotmail.com      Allen
#
#      last_name country
# 0        Kutch     USA
# 1         Wiza     USA
# 2       Littel     USA
# 3       Stokes     USA
# 4     Prosacco     USA
# ...        ...     ...
# 9995     Klein     USA
# 9996     Kunze     USA
# 9997   Bartell     USA
# 9998     Block     USA
# 9999    Hammes     USA
#
# [10000 rows x 7 columns]

# %% [markdown]
# Cleaning DF 3

# %%
df_3 = pd.read_csv("only_wood_customer_us_3.csv", sep='\t', skiprows=1,
            names = ['gender', 'name', 'email', 'age', 'city', 'country'])
            
df_3.gender = df_3.gender.replace({'string_Male': 'Male', 'string_Female': 'Female', 
                                        'boolean_1': 'Female', 'boolean_0': 'Male', 'character_M': 'Male', 'character_F': 'Female'})

df_3.name = df_3.name.str.replace('string_', '')
df_3.name = df_3.name.str.replace('\W', ' ')
name_df = df_3.name.str.split(expand=True)
df_3['first_name'], df_3['last_name'] = name_df[0], name_df[1]
df_3.drop('name', axis=1, inplace=True)
df_3.first_name = df_3.first_name.str.title()
df_3.last_name = df_3.last_name.str.title()

df_3.email = df_3.email.str.replace('string_', '')

df_3.age = df_3.age.str.replace('\D', '')
df_3.age = df_3.age.astype(int)

df_3.city = df_3.city.str.replace('string_', '')
df_3.city = df_3.city.str.replace('_', '-')
df_3.city = df_3.city.str.title()

df_3.country = 'USA'

# %%
df_1.columns = ['gender', 'first_name', 'last_name', 'user_name', 'email', 'age', 'city', 'country']
df_1
# Out:
#       gender first_name last_name user_name                       email  age  \
# 0     Female    Latesha    Barton   latesha         forgottoask@woodinc   85
# 1     Female    Yolando      Jast   yolando      yolando_jast@yahoo.com   53
# 2       Male      Stacy   Johnson     stacy     stacy.johnson@yahoo.com   64
# 3       Male      Abdul    Mayert     abdul    mayert.abdul@hotmail.com   79
# 4       Male     Julius   Reinger    julius  reinger_julius@hotmail.com   65
# ...      ...        ...       ...       ...                         ...  ...
# 9995    Male      Young      Koch     young      koch_young@hotmail.com   44
# 9996    Male      Craig     Runte     craig       craig.runte@gmail.com   29
# 9997  Female      Leora   Trantow     leora   trantow.leora@hotmail.com   97
# 9998  Female       Nery    Heller      nery     heller_nery@hotmail.com   86
# 9999  Female      Linda   Dickens     linda     dickens.linda@yahoo.com   58
#
#               city country
# 0     Indianapolis     USA
# 1         Columbus     USA
# 2     Indianapolis     USA
# 3          Phoenix     USA
# 4     Jacksonville     USA
# ...            ...     ...
# 9995  Jacksonville     USA
# 9996  Indianapolis     USA
# 9997      New-York     USA
# 9998      New-York     USA
# 9999     San Diego     USA
#
# [10000 rows x 8 columns]

# %% [markdown]
# Concat dfs

# %%
df = pd.concat([df_1, df_2, df_3], ignore_index=True)
df.drop('user_name', axis=1, inplace=True)

df
# Out:
#        gender  first_name last_name                        email age  \
# 0      Female     Latesha    Barton          forgottoask@woodinc  85
# 1      Female     Yolando      Jast       yolando_jast@yahoo.com  53
# 2        Male       Stacy   Johnson      stacy.johnson@yahoo.com  64
# 3        Male       Abdul    Mayert     mayert.abdul@hotmail.com  79
# 4        Male      Julius   Reinger   reinger_julius@hotmail.com  65
# ...       ...         ...       ...                          ...  ..
# 29995    Male        Russ   Effertz       RUSS.EFFERTZ@GMAIL.COM  39
# 29996  Female      Temeka   Padberg   PADBERG_TEMEKA@HOTMAIL.COM  95
# 29997    Male  Alessandra    Fisher  ALESSANDRA_FISHER@YAHOO.COM  24
# 29998  Female      Virgie    Blanda    virgie.blanda@hotmail.com  59
# 29999    Male  Kristopher     Terry   Kristopher.terry@yahoo.com  53
#
#                city country
# 0      Indianapolis     USA
# 1          Columbus     USA
# 2      Indianapolis     USA
# 3           Phoenix     USA
# 4      Jacksonville     USA
# ...             ...     ...
# 29995       Chicago     USA
# 29996  Indianapolis     USA
# 29997        Dallas     USA
# 29998       Phoenix     USA
# 29999      San-Jose     USA
#
# [30000 rows x 7 columns]

# %%
conn = sql.connect('wood.db')
c = conn.cursor()

c.execute("drop table if exists wood")
c.execute('''
            create table wood 
            (gender text,
            first_name text,
            last_name text,
            email text,
            age int,
            city text,
            country text,
            created_at text,
            referral text
            )
            ''')

for index,rows in df.iterrows():
    c.execute('insert into wood values (?, ?, ?, ?, ?, ?, ?, ?, ?)', (rows['gender'], rows['first_name'], 
                    rows['last_name'], rows['email'], rows['age'], rows['city'], rows['country'], '', ''))

# %%
for i, row in enumerate(c.execute("select * from wood")):
    print(row)
    if i == 10:
        break
    

c.close()
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-88-a10bf2a45008> in <module>
# ----> 1 for i, row in enumerate(c.execute("select * from wood")):
#       2     print(row)
#       3     if i == 10:
#       4         break
#       5
#
# ProgrammingError: Cannot operate on a closed cursor.
